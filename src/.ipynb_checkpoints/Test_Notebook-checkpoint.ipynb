# %%
import resilience_tracker as rt
import reader as reader
import matplotlib.pyplot as plt
# Out:
# C:\Program Files\Anaconda\lib\site-packages\skimage\_shared\utils.py:8: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.5)
#   import scipy

# %%
filename = 'D:\\Actin Channel\\50224\\1-3\\@4x 1h20 1-3 10minvid'
output_filename = os.path.join(filename + ' BARCODE Output', 'Channel 0')
filepath = filename + '.nd2'
file = reader.read_file(filepath)
# Out:
# D:\Actin Channel\50224\1-3\@4x 1h20 1-3 10minvid.nd2

# %%
file[:,:,:,0].shape
# Out:
# (560, 512, 512)

# %%
_, _, _, _, _, _, _, r = rt.check_resilience(file, output_filename, 0, 0.5, 20, 0.9, 1.0, True, False, True)
# Out:
# Beginning Resilience Testing...
# Image dimensions: 262144
# Largest void area: [15559, 15531, 15526, 15493, 15489, 15486, 15476, 15462, 15426, 15416, 15390, 15375, 15328, 15319, 15314, 15300, 15293, 15291, 15259, 15238, 15204, 15204, 15153, 15113, 15081, 8741, 8721, 8720, 8716]
# Initial void area: 15117.0
# Void proportions: [1.00238142 0.99761858 0.57690018 0.9997354  0.57656943 0.57683403
#  0.57822319 1.00575511 1.01151022 1.00575511 1.00800423 1.01210558
#  1.0093934  1.01164252 1.01303169 1.01336244 1.0139578  1.01706688
#  1.01805914 1.01977906 1.02044056 1.02282199 1.02440961 1.0237481
#  1.02460806 1.02487266 1.02705563 1.02738639 1.02923861]

# %%
for i in range(len(r)):
    max_area = max(r[i], key = lambda reg: reg.area)
    print(max_area.area)
# Out:
# 1027
# 831
# 1029
# 1042
# 1043
# 1063
# 1025
# 1023
# 1003
# 994
# 961
# 956
# 953
# 948
# 940
# 915
# 912
# 899
# 868
# 854
# 837
# 838
# 825
# 809
# 788
# 793
# 766
# 760

# %%
plt.imshow(rt.binarize(file[0,:,:,0], 0.1), cmap='gray')
